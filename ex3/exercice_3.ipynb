# %%
import numpy as np
import pandas as pd
from sklearn import model_selection
from sklearn import tree
from sklearn.metrics import accuracy_score
import os
from pathlib import Path
from matplotlib import pyplot as plt

# %%
data_folder = Path("../data/classification_NBA/")

inputs = np.load(data_folder / "inputs.npy")
labels = np.load(data_folder / "labels.npy")

# %% [markdown]
# ## Decision tree

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(inputs, labels, test_size=0.20, random_state=42)
clf = tree.DecisionTreeClassifier(criterion = 'entropy', random_state=42, max_depth=5, min_samples_leaf=3).fit(X_train, y_train)

# %%
plt.figure(figsize=(18,10))
tree.plot_tree(clf)
plt.show()

# %%
scores = model_selection.cross_val_score(clf, X_train, y_train, cv=5)
print(scores)
# Out:
# [0.725  0.75   0.65   0.8125 0.7625]

# %%
prediction = clf.predict(X_test)
test = accuracy_score(y_test, prediction)
print(test)
# Out:
# 0.77

# %% [markdown]
# Après expérimentation, les meilleures performances obtensible par un arbre de décision est de 75% de précision avec une profondeur de 5.

# %% [markdown]
# ## Support vector machine

# %%
from sklearn import svm

clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# /home/tristan/anaconda3/envs/ml/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
scores = model_selection.cross_val_score(clf, X_train, y_train, cv=5)
print(scores)
# Out:
# [0.825  0.8625 0.875  0.8875 0.8   ]
# /home/tristan/anaconda3/envs/ml/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/tristan/anaconda3/envs/ml/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/tristan/anaconda3/envs/ml/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
prediction = clf.predict(X_test)
test = accuracy_score(y_test, prediction)
print(test)
# Out:
# 0.82

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression().fit(X_train, y_train)
# Out:
# /home/tristan/anaconda3/envs/ml/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
scores = model_selection.cross_val_score(clf, X_train, y_train, cv=5)
print(scores)
# Out:
# [0.875  0.9375 0.9    0.8625 0.8625]
# /home/tristan/anaconda3/envs/ml/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/tristan/anaconda3/envs/ml/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/tristan/anaconda3/envs/ml/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
prediction = clf.predict(X_test)
test = accuracy_score(y_test, prediction)
print(test)
# Out:
# 0.8
